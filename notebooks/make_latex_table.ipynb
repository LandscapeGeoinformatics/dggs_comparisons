s2	8	388775	847.14	1632.39	1297.99	1316.01	0.653	1.258	0.152"""

# %%
import pandas as pd
import io

df = pd.read_table(io.StringIO(table))
df
# Out:
#           base_dggs  resolution  num_cells    area_min    area_max  \
# 0   DGGRID_FULLER3H           2         80  4001171.41  5919260.19
# 1   DGGRID_FULLER3H           3        249  1452314.69  1992181.54
# 2   DGGRID_FULLER3H           4        772   431623.16   661522.06
# 3   DGGRID_FULLER3H           5       2357   197043.85   221665.52
# 4   DGGRID_FULLER3H           6       7132    65479.90    73913.82
# ..              ...         ...        ...         ...         ...
# 61               s2           4       1487   230356.53   413477.54
# 62               s2           5       6017    53916.34   104571.36
# 63               s2           6      24201    13586.00    26103.04
# 64               s2           7      97065     3384.90     6530.37
# 65               s2           8     388775      847.14     1632.39
#
#      area_mean  area_median  norm_area_min  norm_area_max  norm_area_std
# 0   5533242.12   5676562.84          0.723          1.070          0.099
# ...

# %%
for idx, row in df.iterrows():
    s = " & ".join([str(i) for i in row.to_list()])
    s = s + r" \\"
    print(s)
# Out:
# DGGRID_FULLER3H & 2 & 80 & 4001171.41 & 5919260.19 & 5533242.12 & 5676562.84 & 0.723 & 1.07 & 0.099 \\
# DGGRID_FULLER3H & 3 & 249 & 1452314.69 & 1992181.54 & 1876370.84 & 1902774.98 & 0.774 & 1.062 & 0.047 \\
# DGGRID_FULLER3H & 4 & 772 & 431623.16 & 661522.06 & 628614.56 & 630816.92 & 0.687 & 1.052 & 0.041 \\
# DGGRID_FULLER3H & 5 & 2357 & 197043.85 & 221665.52 & 209884.83 & 209551.23 & 0.939 & 1.056 & 0.029 \\
# DGGRID_FULLER3H & 6 & 7132 & 65479.9 & 73913.82 & 69983.67 & 69924.25 & 0.936 & 1.056 & 0.029 \\
# DGGRID_FULLER4D & 2 & 146 & 2929864.61 & 3315294.52 & 3152695.53 & 3171342.81 & 0.929 & 1.052 & 0.033 \\
# DGGRID_FULLER4D & 3 & 608 & 735280.41 & 835934.61 & 795033.54 & 792457.46 & 0.925 & 1.051 & 0.029 \\
# DGGRID_FULLER4D & 4 & 2484 & 184680.02 & 210383.21 & 199157.53 & 199152.79 & 0.927 & 1.056 & 0.029 \\
# DGGRID_FULLER4D & 5 & 10036 & 46493.56 & 52631.67 & 49810.85 & 49780.98 & 0.933 & 1.057 & 0.029 \\
# ...

# %%
len(row)
# Out:
# 10

# %%
"""base_dggs 	resolution 	num_cells 	area_min 	area_max 	area_mean 	area_median 	norm_area_min 	norm_area_max 	norm_area_std""".replace("\t", " & ").replace("_", " ")
# Out:
# 'base dggs  & resolution  & num cells  & area min  & area max  & area mean  & area median  & norm area min  & norm area max  & norm area std'

# %%
t2 = """base_dggs	resolution	num_cells	area_min	area_max	area_mean	area_median	norm_area_min	norm_area_max	norm_area_std	ipq_min	ipq_max	ipq_mean	ipq_std
DGGRID_FULLER3H	2	80	4001171.41	5919260.19	5533242.12	5676562.84	0.723	1.070	0.099	0.865	0.905	0.900	0.013
DGGRID_FULLER3H	3	249	1452314.69	1992181.54	1876370.84	1902774.98	0.774	1.062	0.047	0.865	0.907	0.900	0.007
DGGRID_FULLER3H	4	772	431623.16	661522.06	628614.56	630816.92	0.687	1.052	0.041	0.865	0.907	0.902	0.004
rhpix	3	4249	116319.50	117136.39	116608.04	116544.28	0.998	1.005	0.002	0.608	0.785	0.755	0.046
rhpix	4	38731	12924.37	13015.26	12956.74	12949.59	0.998	1.005	0.002	0.595	0.785	0.754	0.048
rhpix	5	349548	1436.04	1446.24	1439.65	1438.84	0.997	1.005	0.002	0.589	0.785	0.753	0.049
s2	2	85	4834716.78	5961481.29	5185449.04	5066762.39	0.932	1.150	0.075	0.746	0.784	0.767	0.014
s2	3	364	1050415.59	1649452.57	1322307.82	1358029.39	0.794	1.247	0.137	0.716	0.785	0.767	0.017
s2	4	1487	230356.53	413477.54	332136.76	339185.71	0.694	1.245	0.149	0.698	0.785	0.767	0.018
s2	5	6017	53916.34	104571.36	83098.32	84459.32	0.649	1.258	0.151	0.688	0.785	0.767	0.018
s2	6	24201	13586.00	26103.04	20773.00	21021.96	0.654	1.257	0.151	0.683	0.785	0.767	0.018
s2	7	97065	3384.90	6530.37	5192.47	5263.77	0.652	1.258	0.152	0.681	0.785	0.767	0.018
s2	8	388775	847.14	1632.39	1297.99	1316.01	0.653	1.258	0.152	0.680	0.785	0.767	0.018"""

# %%
df2 = pd.read_table(io.StringIO(t2))
df2

df2 = df2.drop(columns=["area_median"])

# %%
headers = [ s.replace("_", " ") for s in df2.columns.to_list()]
s = " & ".join([str(i) for i in headers])
s = s + r" \\"
s = s.replace("norm", "norm.").replace("base", "")
print(s)
# Out:
#  dggs & resolution & num cells & area min & area max & area mean & norm. area min & norm. area max & norm. area std & ipq min & ipq max & ipq mean & ipq std \\

# %%
len(headers)
# Out:
# 13

# %%
for idx, row in df2.iterrows():
    s = " & ".join([str(i).replace("_", " ") for i in row.to_list()])
    s = s + r" \\"
    s = s.replace("eaggr", "O.EAGGR").replace("rhpix", "rHEALPix").replace("s2", "S2").replace("h3", "H3")
    print(s)
# Out:
# DGGRID FULLER3H & 2 & 80 & 4001171.41 & 5919260.19 & 5533242.12 & 0.723 & 1.07 & 0.099 & 0.865 & 0.905 & 0.9 & 0.013 \\
# DGGRID FULLER3H & 3 & 249 & 1452314.69 & 1992181.54 & 1876370.84 & 0.774 & 1.062 & 0.047 & 0.865 & 0.907 & 0.9 & 0.007 \\
# DGGRID FULLER3H & 4 & 772 & 431623.16 & 661522.06 & 628614.56 & 0.687 & 1.052 & 0.041 & 0.865 & 0.907 & 0.902 & 0.004 \\
# DGGRID FULLER3H & 5 & 2357 & 197043.85 & 221665.52 & 209884.83 & 0.939 & 1.056 & 0.029 & 0.891 & 0.907 & 0.901 & 0.004 \\
# DGGRID FULLER3H & 6 & 7132 & 65479.9 & 73913.82 & 69983.67 & 0.936 & 1.056 & 0.029 & 0.891 & 0.907 & 0.901 & 0.003 \\
# DGGRID FULLER4D & 2 & 146 & 2929864.61 & 3315294.52 & 3152695.53 & 0.929 & 1.052 & 0.033 & 0.632 & 0.73 & 0.676 & 0.031 \\
# DGGRID FULLER4D & 3 & 608 & 735280.41 & 835934.61 & 795033.54 & 0.925 & 1.051 & 0.029 & 0.63 & 0.74 & 0.677 & 0.031 \\
# DGGRID FULLER4D & 4 & 2484 & 184680.02 & 210383.21 & 199157.53 & 0.927 & 1.056 & 0.029 & 0.629 & 0.745 & 0.677 & 0.031 \\
# ...
